# %% [markdown]
# 1.) Load The Data

# %%
import pandas as pd
k = pd.read_csv("Mobile Price Classification.csv")

# %%
k
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# 5              1859     0          0.5         1   3       0          22
# 6              1821     0          1.7         0   4       1          10
# 7              1954     0          0.5         1   0       0          24
# 8              1445     1          0.5         0   0       0          53
# 9               509     1          0.6         1   2       1           9
# 10              769     1          2.9         1   0       0           9
# 11             1520     1          2.2         0   5       1          33
# ...

# %% [markdown]
# 2.)Describe the data in multiple- way

# %%
k.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# ...

# %% [markdown]
# data Information

# %%
k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
# battery_power    2000 non-null int64
# blue             2000 non-null int64
# clock_speed      2000 non-null float64
# dual_sim         2000 non-null int64
# fc               2000 non-null int64
# four_g           2000 non-null int64
# int_memory       2000 non-null int64
# m_dep            2000 non-null float64
# mobile_wt        2000 non-null int64
# n_cores          2000 non-null int64
# pc               2000 non-null int64
# px_height        2000 non-null int64
# px_width         2000 non-null int64
# ram              2000 non-null int64
# sc_h             2000 non-null int64
# sc_w             2000 non-null int64
# talk_time        2000 non-null int64
# three_g          2000 non-null int64
# touch_screen     2000 non-null int64
# wifi             2000 non-null int64
# price_range      2000 non-null int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
k.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %% [markdown]
# ## There are:
# 1) 2000 rows
# 2) 21 columns
# 3) columns are
# battery_power,             dual_sim ,          fc four_g
# blue,                      clock_speed,        four_g
# fc: front camera,          int_memory,          m_dep
# mobile_wt,                 n_cores,             px_height
# px_width,                  ram ,                sc_h
# sc_w,                      talk_time,           three_g
# touch_screen,              wifi,                price_range

# %%
k.describe().sum()
# Out:
# battery_power     9869.936706
# blue              2002.995100
# clock_speed       2010.238254
# dual_sim          2004.009535
# fc                2038.650944
# four_g            2004.021162
# int_memory        2212.192215
# m_dep             2003.390166
# mobile_wt         2875.648655
# n_cores           2029.808337
# pc                2065.980815
# px_height         6842.888811
# px_width          9936.464947
# ram              15881.445044
# sc_h              2077.519745
# sc_w              2044.123398
# talk_time         2071.474955
# three_g           2005.187773
# touch_screen      2004.003116
# wifi              2004.007076
# price_range       2010.118314
# dtype: float64

# %%
type(k)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 3.) Remove Insignificant columns

# %%
k.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
k.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# ...

# %% [markdown]
# clearly, there is no insignificant column in the data

# %% [markdown]
# 4.)Check Missing value for each columns

# %%
k.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# There is no missing value in the data.

# %% [markdown]
# 5.)Remove rows with missing values

# %%
k.notnull()
# Out:
#       battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0              True  True         True      True  True    True        True
# 1              True  True         True      True  True    True        True
# 2              True  True         True      True  True    True        True
# 3              True  True         True      True  True    True        True
# 4              True  True         True      True  True    True        True
# 5              True  True         True      True  True    True        True
# 6              True  True         True      True  True    True        True
# 7              True  True         True      True  True    True        True
# 8              True  True         True      True  True    True        True
# 9              True  True         True      True  True    True        True
# 10             True  True         True      True  True    True        True
# ...

# %%
k.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# there is no row with missing values.

# %% [markdown]
# 5.)Formatting your Data – making data types compaitable with other data types.

# %%
k
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# 5              1859     0          0.5         1   3       0          22
# 6              1821     0          1.7         0   4       1          10
# 7              1954     0          0.5         1   0       0          24
# 8              1445     1          0.5         0   0       0          53
# 9               509     1          0.6         1   2       1           9
# 10              769     1          2.9         1   0       0           9
# 11             1520     1          2.2         0   5       1          33
# ...

# %% [markdown]
# the data is already in comaptible form . This is because there are only two data types i.e 1)int 2)float
# the column with float value has only float values. for example-m_dep
